# %% [markdown]
# <h1 style="margin-bottom: 25px;font-size:3.5rem;color:#4c76ce;text-align:center;">
#     Getting Started with Pandas</h1>
#
# <h2 style="margin-bottom: 25px;font-size:2.5rem;text-align:center;">
#     Part I - Data Structures: Pandas Series</h2>
#
# <img src="https://raw.githubusercontent.com/lajmcourses/Images/master/pandas.png"
#      style="position:absolute;top:5px;left:25px;height:150px;width:auto;margin-bottom:25px;">

# %% [markdown]
# ## What is Pandas?

# %% [markdown]
# Pandas is a data science library used for data manipulation, analysis and cleaning. It is one of the most important Python libraries for Data Analysis. Pandas is built on top of NumPy.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# Getting version of Pandas
print("My Pandas version:", pd.__version__)
# Out:
# My Pandas version: 1.5.3

# %% [markdown]
# ## Key Data Structures in Pandas
#
# A **series** is a one-dimensional labeled array capable of holding data of any type (integer, string, float, etc.). The axis labels are called index. Pandas series is similar to a column in Excel spredsheet.
#
#
# A **dataframe** is a most widely used data structure in Pandas. It is used to represent tabular data, and it is similar to a table in Excel.

# %% [markdown]
# ## Pandas Series
#
# A **Series** is a one-dimensional array-like object containing a sequence of values and an associated array of data labels, called **index**.

# %%
# Series

pd_series = pd.Series([4, -1, 0, 2, -1, -4, -3, -3, -2, -3])
print("\nInitial Pandas series:", pd_series)

# Series values
print("\nSeries values:", pd_series.values)

# Series name
print("\nInitial series name:\n", pd_series.name)
pd_series.name = "Temperature Observations"
print("\nUpdated series name:\n", pd_series.name)

# Series index
print("\nDefault Series Index: ", pd_series.index)
dts = pd.date_range("2022-01-07", periods=len(pd_series), freq="D")
print(dts)
pd_series.index = dts

print("\nUpdated eries Index: ", pd_series.index)

# Updated Series
print("\nUpdates Pandas series:\n", pd_series)
# Out:
# Initial Pandas series: 0    4
# 1   -1
# 2    0
# 3    2
# 4   -1
# 5   -4
# 6   -3
# 7   -3
# 8   -2
# 9   -3
# dtype: int64
#
# Series values: [ 4 -1  0  2 -1 -4 -3 -3 -2 -3]
#
# Initial series name:
#  None
#
# Updated series name:
#  Temperature Observations
#
# Default Series Index:  RangeIndex(start=0, stop=10, step=1)
# DatetimeIndex(['2022-01-07', '2022-01-08', '2022-01-09', '2022-01-10',
#                '2022-01-11', '2022-01-12', '2022-01-13', '2022-01-14',
#                '2022-01-15', '2022-01-16'],
#               dtype='datetime64[ns]', freq='D')
#
# Updated eries Index:  DatetimeIndex(['2022-01-07', '2022-01-08', '2022-01-09', '2022-01-10',
#                '2022-01-11', '2022-01-12', '2022-01-13', '2022-01-14',
#                '2022-01-15', '2022-01-16'],
#               dtype='datetime64[ns]', freq='D')
#
# Updates Pandas series:
#  2022-01-07    4
# 2022-01-08   -1
# 2022-01-09    0
# 2022-01-10    2
# 2022-01-11   -1
# 2022-01-12   -4
# 2022-01-13   -3
# 2022-01-14   -3
# 2022-01-15   -2
# 2022-01-16   -3
# Freq: D, Name: Temperature Observations, dtype: int64

# %% [markdown]
# ## Exercise 1: Creating a Series from a Dictionary
#
# In the example above, we have seen that the simplest Pandas Series is created from a list. It is also possible to create the Series from a dictionary.
#
# Try to create a series from the dictionary given below:
#
# population = {
#     "Estonia": "1328000",
#     "Latvia": "1893000",
#     "Lithuania": "2810000"
# }
#
# a) Answer the questions:
#
# **What is the index of the newly created series?**
#
# **What are the values of the newly created series?**
#
# b) Set series name to *Baltic States Population* and print the series.

# %% [markdown]
# ## Solution to Exercise 1:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


baltic_population = { "Estonia": 1328000, "Latvia": 1893000, "Lithuania": 2810000 }

baltic_population_data = pd.Series(baltic_population, dtype="float64")
print("\nBaltic population data:\n", baltic_population_data)

print("\nSeries Index:", baltic_population_data.index)

print("\nSeries values:", baltic_population_data.values)

baltic_population_data.name = "Baltic States Population"
print("\nUpdated series name:", baltic_population_data.name)

print("\n Update Baltic population data:\n", baltic_population_data)
# Out:
# Baltic population data:
#  Estonia      1328000.0
# Latvia       1893000.0
# Lithuania    2810000.0
# dtype: float64
#
# Series Index: Index(['Estonia', 'Latvia', 'Lithuania'], dtype='object')
#
# Series values: [1328000. 1893000. 2810000.]
#
# Updated series name: Baltic States Population
#
#  Update Baltic population data:
#  Estonia      1328000.0
# Latvia       1893000.0
# Lithuania    2810000.0
# Name: Baltic States Population, dtype: float64

# %% [markdown]
# ## Accessing Elements of a Series

# %%
import pandas as pd

# Create series
series_data = [4, -1, 0, 2, -1, -4, -3, -3, -2, -3]
series_index = pd.date_range("2022-01-07", periods=len(series_data), freq="D")
pd_series = pd.Series(data=series_data, index=series_index, dtype=float, name="Temperature Observations")

print("\nTemperature Observation Series:\n", pd_series)

# Accessing a single element
print("\nAccessing a single element by numerical index:", pd_series[0])

# Accessing element using iloc
print("\nAccessing an element using iloc:", pd_series.iloc[0])

# Accessing an element using index
print("\nAccessing an element by index:", pd_series["2022-01-07"])

# Accessing an element using loc
print("\nAccessing an element using loc:", pd_series.loc["2022-01-07"])
# Out:
# Temperature Observation Series:
#  2022-01-07    4.0
# 2022-01-08   -1.0
# 2022-01-09    0.0
# 2022-01-10    2.0
# 2022-01-11   -1.0
# 2022-01-12   -4.0
# 2022-01-13   -3.0
# 2022-01-14   -3.0
# 2022-01-15   -2.0
# 2022-01-16   -3.0
# Freq: D, Name: Temperature Observations, dtype: float64
#
# Accessing a single element by numerical index: 4.0
#
# Accessing an element using iloc: 4.0
#
# Accessing an element by index: 4.0
#
# Accessing an element using loc: 4.0

# %% [markdown]
# <h2 style="color:tomato;">Pay Attention:</h2>
#
# It is recommended to use **loc** and **iloc** when accessing Pandas series (and dataframe) data.
#
# **loc** - label based position
#
# **iloc** - integer based position

# %% [markdown]
# ## Accessing Multiple Elements of a Series

# %%
import pandas as pd

# Create series
series_data = [4, -1, 0, 2, -1, -4, -3, -3, -2, -3]
series_index = pd.date_range("2022-01-07", periods=len(series_data), freq="D")
pd_series = pd.Series(data=series_data, index=series_index, dtype=float, name="Temperature Observations")

print("\nTemperature Observation Series:\n", pd_series)

# Accessing multiple elements
print("Accessing multiple Series elements:")
print(pd_series[[0, 2, 4]])

# Accessing multiple elements using iloc
print("\nAccessing multiple Series elements with iloc:")
print(pd_series.iloc[[0, 2, 4]])

# Accessing multiple elements by index
print("\nAccessing multiple Series elements:")
print(pd_series[["2022-01-07", "2022-01-09", "2022-01-11"]])

# Accessing multiple elements by index with loc
print("\nAccessing multiple Series elements:")
print(pd_series.loc[["2022-01-07", "2022-01-09", "2022-01-11"]])
# Out:
# Temperature Observation Series:
#  2022-01-07    4.0
# 2022-01-08   -1.0
# 2022-01-09    0.0
# 2022-01-10    2.0
# 2022-01-11   -1.0
# 2022-01-12   -4.0
# 2022-01-13   -3.0
# 2022-01-14   -3.0
# 2022-01-15   -2.0
# 2022-01-16   -3.0
# Freq: D, Name: Temperature Observations, dtype: float64
# Accessing multiple Series elements:
# 2022-01-07    4.0
# 2022-01-09    0.0
# 2022-01-11   -1.0
# Freq: 2D, Name: Temperature Observations, dtype: float64
#
# Accessing multiple Series elements with iloc:
# 2022-01-07    4.0
# 2022-01-09    0.0
# 2022-01-11   -1.0
# Freq: 2D, Name: Temperature Observations, dtype: float64
#
# Accessing multiple Series elements:
# 2022-01-07    4.0
# 2022-01-09    0.0
# 2022-01-11   -1.0
# Name: Temperature Observations, dtype: float64
#
# Accessing multiple Series elements:
# 2022-01-07    4.0
# 2022-01-09    0.0
# 2022-01-11   -1.0
# Name: Temperature Observations, dtype: float64

# %% [markdown]
# ## Filtering Elements of a Series

# %%
import pandas as pd

# Create series
series_data = [4, -1, 0, 2, -1, -4, -3, -3, -2, -3]
series_index = pd.date_range("2022-01-07", periods=len(series_data), freq="D")
pd_series = pd.Series(data=series_data, index=series_index, dtype=float, name="Temperature Observations")

print("\nTemperature Observation Series:\n", pd_series)

# Selecting nonnegative elements
print("\nNonnegative temperatures:\n", pd_series[pd_series >= 0])


# Selecting elements with date > 2022-01-10
print("\nTemperatures after 20022-01-10:\n", pd_series[pd_series.index > "2022-01-10"])
# Out:
# Temperature Observation Series:
#  2022-01-07    4.0
# 2022-01-08   -1.0
# 2022-01-09    0.0
# 2022-01-10    2.0
# 2022-01-11   -1.0
# 2022-01-12   -4.0
# 2022-01-13   -3.0
# 2022-01-14   -3.0
# 2022-01-15   -2.0
# 2022-01-16   -3.0
# Freq: D, Name: Temperature Observations, dtype: float64
#
# Nonnegative temperatures:
#  2022-01-07    4.0
# 2022-01-09    0.0
# 2022-01-10    2.0
# Name: Temperature Observations, dtype: float64
#
# Temperatures after 20022-01-10:
#  2022-01-11   -1.0
# 2022-01-12   -4.0
# 2022-01-13   -3.0
# 2022-01-14   -3.0
# 2022-01-15   -2.0
# 2022-01-16   -3.0
# Freq: D, Name: Temperature Observations, dtype: float64

# %% [markdown]
# ## Exercise 2: G7 Countries I

# %% [markdown]
# a) Create a series containing G7 countries population in millions. Save the newly created series as *g7_population*
#
# b) Add the series name: *G7 Countries Population*
#
# c) Print out the population of Italy.
#
# d) Print out the population of France and Canada. Use *loc*.
#
# e) Select countries with the population greater than 100 mln.Use conditional filtering to solve the problem.
#
# f) Select G7 countries with population higher than 50 millions and less than 100 millions.
# Use conditional filtering to solve the problem.

# %% [markdown]
# ## Solution to Exercise 2:

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# Create G7 Population Series
g7_data = {
    "Canada": 38.25,
    "France": 67.75,
    "Germany": 83.2,
    "Italy": 59.11,
    "Japan": 125.70,
    "United Kingdom": 67.33,
    "United States": 331.90
}

g7_population = pd.Series(g7_data)
print(g7_population)

g7_population.name = "G7 Countries Population"
print("\nUpdated series name:", g7_population.name)

print("\nPopulation of Italy:", g7_population['Italy'] )

print("\nPopulation of France and Canada:\n", g7_population.loc[["France", "Canada"]] )
#print("\nPopulation of Canada:", g7_population.loc['Canada'] )

print("\nCountries with the population > 100 mln:\n", g7_population[g7_population > 100])

print("\nCountries with the population 50-100 mln:\n", g7_population[ (g7_population > 50) & (g7_population < 100) ])
# Out:
# Canada             38.25
# France             67.75
# Germany            83.20
# Italy              59.11
# Japan             125.70
# United Kingdom     67.33
# United States     331.90
# dtype: float64
#
# Updated series name: G7 Countries Population
#
# Population of Italy: 59.11
#
# Population of France and Canada:
#  France    67.75
# Canada    38.25
# Name: G7 Countries Population, dtype: float64
#
# Countries with the population > 100 mln:
#  Japan            125.7
# United States    331.9
# Name: G7 Countries Population, dtype: float64
#
# Countries with the population 50-100 mln:
#  France            67.75
# Germany           83.20
# Italy             59.11
# United Kingdom    67.33
# Name: G7 Countries Population, dtype: float64

# %% [markdown]
# ## Exercise 3: G7 Countries II
#
# 1. Verify with the code that the data type returned by executing the expression below returns the Pandas series.
#
# ```
# g7_population > 100
#
# ```
# 2. What type of values this series contain? What is the interpretation of these values?
#
# 3. Suppose that we have a country in G7 dataset with the population of exactly 100 millions. What value would we get for such a country?

# %% [markdown]
# ## Solution to Exericise 3:

# %%
flt = g7_population > 100
print("\nG7 population > 100:\n",flt)
print(type(flt))

flt1 = g7_population < 50
print("\nG7 population < 50:\n",flt1)
print(type(flt1))

print("\nG7 population >100 and < 50:\n", g7_population[flt | flt1])
# Out:
# G7 population > 100:
#  Canada            False
# France            False
# Germany           False
# Italy             False
# Japan              True
# United Kingdom    False
# United States      True
# Name: G7 Countries Population, dtype: bool
# <class 'pandas.core.series.Series'>
#
# G7 population < 50:
#  Canada             True
# France            False
# Germany           False
# Italy             False
# Japan             False
# United Kingdom    False
# United States     False
# Name: G7 Countries Population, dtype: bool
# <class 'pandas.core.series.Series'>
#
# G7 population >100 and < 50:
#  Canada            38.25
# Japan            125.70
# United States    331.90
# Name: G7 Countries Population, dtype: float64

# %% [markdown]
# ## Series Data Manipulation

# %%
# Reverting the Series

x = pd.Series([1, 2, 3, 4, 5], index=["first", "second", "third", "fourth", "fifth"])
print("\nInitial Series x:\n", x)

print("\nReverted Series X:\n", x[::-1])
# Out:
# Initial Series x:
#  first     1
# second    2
# third     3
# fourth    4
# fifth     5
# dtype: int64
#
# Reverted Series X:
#  fifth     5
# fourth    4
# third     3
# second    2
# first     1
# dtype: int64

# %%
# Sorting

unsorted_series = pd.Series([100, 12, 103, 56, 98, 25, 95])
print("\nUnsorted Series:\n", unsorted_series)

sorted_series = unsorted_series.sort_values()
print("\nSorted Series:\n", sorted_series)
# Out:
# Unsorted Series:
#  0    100
# 1     12
# 2    103
# 3     56
# 4     98
# 5     25
# 6     95
# dtype: int64
#
# Sorted Series:
#  1     12
# 5     25
# 3     56
# 6     95
# 4     98
# 0    100
# 2    103
# dtype: int64

# %% [markdown]
# ## Series Summary Statistisc

# %%
# Create series
series_data = [4, -1, 0, 2, -1, -4, -3, -3, -2, -3]
series_index = pd.date_range("2022-01-07", periods=len(series_data), freq="D")
pd_series = pd.Series(data=series_data, index=series_index, dtype=float, name="Temperature Observations")

print("\nTemperature Observation Series:\n", pd_series)


# Average temperature
t_avg = pd_series.mean()
print("\nAverage temperature:", t_avg)

# Min temperature
t_min = pd_series.min()
print("\nMin. temperature:", t_min)

# Max temperature
t_max = pd_series.max()
print("\nMax temperature:", t_max)

# Sum of all temperatures
t_sum = pd_series.sum()
print("\nSum of temperatures:", t_sum)

# Temperature variance
t_var = pd_series.var()
print("\nTemperature variance:", t_var)

# Temperature standard deviation
t_std = pd_series.std()
print("\nTemperature standard deviation:", t_std)
# Out:
# Temperature Observation Series:
#  2022-01-07    4.0
# 2022-01-08   -1.0
# 2022-01-09    0.0
# 2022-01-10    2.0
# 2022-01-11   -1.0
# 2022-01-12   -4.0
# 2022-01-13   -3.0
# 2022-01-14   -3.0
# 2022-01-15   -2.0
# 2022-01-16   -3.0
# Freq: D, Name: Temperature Observations, dtype: float64
#
# Average temperature: -1.1
#
# Min. temperature: -4.0
#
# Max temperature: 4.0
#
# Sum of temperatures: -11.0
#
# Temperature variance: 6.322222222222223
#
# Temperature standard deviation: 2.5144029554194813

# %% [markdown]
# ## Exercise 4:
#
# 1. Write a Python program to calculate sample mean. Calculate the mean for the **Temperatures** data set given above. Compare the result with the result you got from Padas.
#
# **Sample mean calculation formula**
#
# $$\overline{x} = \frac{1}{n} \times \sum^{n}_{i=1} x_i$$
#
#
#
# 2. Write a Python program to calculate the variance. Calculate the variance for the **Temperatures** data set given above. Compare the result with the result you got from Pandas.
#
# **Sample variance calculation formula:**
#
# $$s^2 = \frac{1}{n-1} \times \sum^{n}_{i=1} (x_i - \overline{x})$$

# %% [markdown]
# ## Solution to Exercise 4:

# %%
series_data = [4, -1, 0, 2, -1, -4, -3, -3, -2, -3]
def average(self):
    return sum(series_data)/len(series_data)
print("\nAverage:",average(series_data))

# The results are identical. 

def variance(self):
    sum = 0
    for i in series_data:
        sum = sum + (i - average(series_data))**2
    return (1/(len(series_data)-1))*sum
print("\nVariance:",variance(series_data))

# The results match. (P.S. there is not enough square in the formula :))
# Out:
# Average: -1.1
#
# Variancce: 6.322222222222223

# %% [markdown]
# ## Plotting a Series with Matplotlib

# %% [markdown]
# ### Plot Example: Line Plot: Stock Price Fluctuations

# %%
import numpy as np
from matplotlib import pyplot as plt

# Let's generate a time series

ndays = 365

stock_price_fluctuations = 0.05 * pd.Series(np.random.randn(ndays),
               index=pd.date_range("2017-01-01", periods=ndays),
               name="Stock Price Fluctuations")

# y_axis = pd.Series(np.zeros(ndays),
#                index=pd.date_range("2017-01-01", periods=ndays),
#                )

print(stock_price_fluctuations)

# Plot
plt.figure(figsize=(10, 5))
plt.plot(stock_price_fluctuations)

# # Add horizontal X-axis
plt.axhline(y=0, linewidth=2, color="green")

# Add plot title
plt.title("\nStock Price Fluctuations Data\n", fontsize=29)

# Update ticks fontsize
plt.xticks(fontsize=15)
plt.yticks(fontsize=12)

# Add plot grid
plt.grid()

# Display plot
plt.show()
# Out:
# 2017-01-01    0.003181
# 2017-01-02   -0.040041
# 2017-01-03    0.007737
# 2017-01-04   -0.074195
# 2017-01-05    0.001434
#                 ...
# 2017-12-27   -0.090664
# 2017-12-28    0.045674
# 2017-12-29    0.011439
# 2017-12-30    0.015423
# 2017-12-31    0.074765
# Freq: D, Name: Stock Price Fluctuations, Length: 365, dtype: float64

# %% [markdown]
# ### Plot Example: Bar Plot: G7 Countries Population

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# Create G7 Population Series
g7_data = {
    "Canada": 38.25,
    "France": 67.75,
    "Germany": 83.2,
    "Italy": 59.11,
    "Japan": 125.70,
    "United Kingdom": 67.33,
    "United States": 331.90
}

# palette = np.round(np.linspace(0, 1, num=10), 1)
colors = mpl.colormaps["Accent"].colors

g7_population = pd.Series(g7_data, name="G7 Population (mln.)")

# print("\nPlotting Data:\n")
# print(g7_population)

# Make the plot
plt.figure(figsize=(10, 5))
p = plt.bar(g7_population.index, g7_population.values, color=colors)

# Add plot title
plt.title("\nG7 Population, mln.\n", fontsize=22)

# Set y-axis label
plt.ylabel("Population, mln.\n", fontsize=14)

# Adjust x-axis ticks
plt.xticks(fontsize=12, rotation=30)

# Adding bar labels
# for k, v in g7_data.items():
#     p = plt.bar(k, v, label=k, color = "green")
plt.bar_label(p, label_type="edge", padding=5)
    
# plt.ylim(0, 400)

# # Display plot
plt.show()

# %% [markdown]
# ### Plot Example: Pie Chart: G7 Population Distribution

# %%
# Pie Chart: G7 Population Distribution

import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# Create G7 Population Series
g7_data = {
    "Canada": 38.25,
    "France": 67.75,
    "Germany": 83.2,
    "Italy": 59.11,
    "Japan": 125.70,
    "United Kingdom": 67.33,
    "United States": 331.90
}

palette = np.round(np.linspace(0, 1, num=10), 1)
colors = mpl.colormaps["Accent"].colors

# Pie Chart Plot
plt.figure(figsize=(10, 7))
plt.title("\nG7 Population Distribution\n", fontsize=20)
plt.pie(g7_data.values(), labels=g7_data.keys(), autopct="%1.0f%%", textprops={'fontsize': 14}, colors=colors)
plt.axis("equal")
plt.show()

# %% [markdown]
# ## Exercise 5: Population of Lithuania

# %% [markdown]
# a) Create a Pandas series containing Lithuania population data from the year 2010 till the year 2020
#
# b) Create a line chart showing the Lithuanian population dynamics.

# %% [markdown]
# ## Solution to Exercise 5:

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
population_data = {2010: 3329039, 2011: 3052588, 2012: 3003641, 2013: 2971905,
                  2014: 2943472, 2015: 2921262, 2016: 2888558, 2017: 2847904,
                   2018: 2808901, 2019: 2794184, 2020: 2794090}
population = pd.Series(population_data)
print(population)
population.name = "Lithuanian population"
print("\nName series:", population.name)

# Convert to millions for easy display on the chart
for i in population.index:
    population.loc[i] = round(population.loc[i]/1000000, 2)
#print(population)
colors = mpl.colormaps["Paired"].colors
plt.figure(figsize=(10, 5))
for i, color in enumerate(colors):
    p = plt.plot(population, marker='s', color=color)
#plt.scatter(population.index, population.values, color="red")
plt.title("\nPopulation of Lithuania from 2010 to 2020 years, mln\n", fontsize=20)
plt.xlabel("Year", fontsize=15 )
plt.ylabel("Population, mln", fontsize=15 )
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xticks(population.index, fontsize=15)
for i in population.index:
    plt.text(i, population.loc[i]+0.02, population.loc[i])
plt.ylim(2.7, 3.4)
plt.grid()
plt.show()
# Out:
# Name series: Lithuanian population

# %% [markdown]
# ## Exercise 6: Baltic States Population
#
# a) Create a series containing the most recent population data of Estonia, Latvia, and Lithuania
#
# b) Create a bar chart showing the population of the three Baltic States.
#
# c) Display population size over each country.
#
# d) Create a pie chart showing population distribution in the Baltic States.

# %% [markdown]
# ## Solution to Exercise 6:

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
baltic_states_population = { "Lithuania": 2860002, 
                            "Latvia": 1891000,
                            "Estonia": 1357739}
population = pd.Series(baltic_states_population)
population.name = "Baltic States Population"
#print(population)
for i in population.index:
    population.loc[i] = round(population.loc[i]/1000000, 2)
print(population)
p = plt.bar(population.index, population.values)
plt.title("\nBaltic States Population in 2023 year, mln\n", fontsize=15)
for i in population.index:
    plt.text(i, population.loc[i]+0.02, population.loc[i])
plt.ylabel("Population, mln", fontsize=10 )
plt.xlabel("Baltic countries", fontsize=10 )
plt.show()

palette = np.round(np.linspace(0, 1, num=10), 1)
colors = mpl.colormaps["Accent"].colors

# Pie Chart Plot
plt.figure(figsize=(10, 5))
plt.title("\nBaltic States Population in 2023 year, mlt\n", fontsize=20)
plt.pie(population.values, labels=population.keys(), autopct="%1.0f%%", textprops={'fontsize': 14}, colors=colors)
plt.axis("equal")
plt.show()
# Out:
# Lithuania    2.86
# Latvia       1.89
# Estonia      1.36
# Name: Baltic States Population, dtype: float64
